# %%
import re
import numpy as np
import assembly_pool as ap
import graph_collection as gc
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from scipy.optimize import curve_fit
from tqdm import tqdm

# %%
gc.main(500,3,10000,np.random.default_rng(42))
# Out:
# Combining Graphs: 100%|██████████| 10000/10000 [00:04<00:00, 2272.78it/s]
# Analyzing result: 100%|██████████| 500/500 [11:59<00:00,  1.44s/it]
# Biggest element size:  30656.0
# Assembly index upper bound:  33.0
